# %% [markdown]
# # Path Diagrams Replication/Generalization
#
# ## Direct Replication (Classic)

# %%
# Out:
# <pre class="mermaid mermaid-js">graph LR
# subgraph O[Original]
#   Gf[Second-order factor] --&gt; F1[Factor 1]
#   Gf --&gt; F2[Factor 2]
#   Gf --&gt; F3[Factor 3]
#
#   F1 --&gt; A[Item A]
#   F1 --&gt; B[Item B]
#   F1 --&gt; C[Item C]
#
#   F2 --&gt; D[Item D]
#   F2 --&gt; E[Item E]
#   F2 --&gt; F[Item F]
#
#   F3 --&gt; G[Item G]
#   F3 --&gt; H[Item H]
#   F3 --&gt; I[Item I]
# end
#
# linkStyle 0 stroke:#d62728,stroke-width:6px;
# linkStyle 3 stroke:#d62728,stroke-width:6px;
#
# subgraph R[Replication]
#   bGf[Second-order factor] --&gt; bF1[Factor 1]
#   bGf --&gt; bF2[Factor 2]
#   bGf --&gt; bF3[Factor 3]
#
#   bF1 --&gt; bA[Item A]
#   bF1 --&gt; bB[Item B]
#   bF1 --&gt; bC[Item C]
#
#   bF2 --&gt; bD[Item D]
#   bF2 --&gt; bE[Item E]
#   bF2 --&gt; bF[Item F]
#
#   bF3 --&gt; bG[Item G]
#   bF3 --&gt; bH[Item H]
#   bF3 --&gt; bI[Item I]
# end
#
# linkStyle 12 stroke:#d62728,stroke-width:6px;
# linkStyle 15 stroke:#d62728,stroke-width:6px;
# O ~~~ R
# </pre>

# %% [markdown]
# ## Conceptual Replication (Classic)

# %%
# Out:
# <pre class="mermaid mermaid-js">graph LR
# subgraph O[Original]
#   Gf[Second-order factor] --&gt; F1[Factor 1]
#   Gf --&gt; F2[Factor 2]
#   Gf --&gt; F3[Factor 3]
#
#   F1 --&gt; A[Item A]
#   F1 --&gt; B[Item B]
#   F1 --&gt; C[Item C]
#
#   F2 --&gt; D[Item D]
#   F2 --&gt; E[Item E]
#   F2 --&gt; F[Item F]
#
#   F3 --&gt; G[Item G]
#   F3 --&gt; H[Item H]
#   F3 --&gt; I[Item I]
# end
#
# linkStyle 0 stroke:#d62728,stroke-width:6px;
# linkStyle 3 stroke:#d62728,stroke-width:6px;
#
# subgraph R[Replication]
#   bGf[Second-order factor] --&gt; bF1[Factor 1]
#   bGf --&gt; bF2[Factor 2]
#   bGf --&gt; bF3[Factor 3]
#
#   bF1 --&gt; bA[Item A]
#   bF1 --&gt; bB[Item B]
#   bF1 --&gt; bC[Item C]
#
#   bF2 --&gt; bD[Item D]
#   bF2 --&gt; bE[Item E]
#   bF2 --&gt; bF[Item F]
#
#   bF3 --&gt; bG[Item G]
#   bF3 --&gt; bH[Item H]
#   bF3 --&gt; bI[Item I]
# end
#
# linkStyle 12 stroke:#d62728,stroke-width:6px;
# linkStyle 17 stroke:#d62728,stroke-width:6px;
# O ~~~ R
# </pre>

# %% [markdown]
# ## Direct Replication (SEM)

# %%
# Out:
# <pre class="mermaid mermaid-js">graph LR
# subgraph O[Original]
#   Gf[Second-order factor] --&gt; F1[Factor 1]
#   Gf --&gt; F2[Factor 2]
#   Gf --&gt; F3[Factor 3]
#
#   F1 --&gt; A[Item A]
#   F1 --&gt; B[Item B]
#   F1 --&gt; C[Item C]
#
#   F2 --&gt; D[Item D]
#   F2 --&gt; E[Item E]
#   F2 --&gt; F[Item F]
#
#   F3 --&gt; G[Item G]
#   F3 --&gt; H[Item H]
#   F3 --&gt; I[Item I]
# end
#
# linkStyle 0 stroke:#d62728,stroke-width:6px;
# linkStyle 3 stroke:#d62728,stroke-width:6px;
# linkStyle 4 stroke:#d62728,stroke-width:6px;
# linkStyle 5 stroke:#d62728,stroke-width:6px;
#
# subgraph R[Replication]
#   bGf[Second-order factor] --&gt; bF1[Factor 1]
#   bGf --&gt; bF2[Factor 2]
#   bGf --&gt; bF3[Factor 3]
#
#   bF1 --&gt; bA[Item A]
#   bF1 --&gt; bB[Item B]
#   bF1 --&gt; bC[Item C]
#
#   bF2 --&gt; bD[Item D]
#   bF2 --&gt; bE[Item E]
#   bF2 --&gt; bF[Item F]
#
#   bF3 --&gt; bG[Item G]
#   bF3 --&gt; bH[Item H]
#   bF3 --&gt; bI[Item I]
# end
#
# ...

# %% [markdown]
# ## Conceptual Replication (SEM)

# %%
# Out:
# <pre class="mermaid mermaid-js">graph LR
# subgraph O[Original]
#   Gf[Second-order factor] --&gt; F1[Factor 1]
#   Gf --&gt; F2[Factor 2]
#   Gf --&gt; F3[Factor 3]
#
#   F1 --&gt; A[Item A]
#   F1 --&gt; B[Item B]
#   F1 --&gt; C[Item C]
#
#   F2 --&gt; D[Item D]
#   F2 --&gt; E[Item E]
#   F2 --&gt; F[Item F]
#
#   F3 --&gt; G[Item G]
#   F3 --&gt; H[Item H]
#   F3 --&gt; I[Item I]
# end
#
# linkStyle 0 stroke:#d62728,stroke-width:6px;
# linkStyle 3 stroke:#d62728,stroke-width:6px;
# linkStyle 4 stroke:#d62728,stroke-width:6px;
#
#
# subgraph R[Replication]
#   bGf[Second-order factor] --&gt; bF1[Factor 1]
#   bGf --&gt; bF2[Factor 2]
#   bGf --&gt; bF3[Factor 3]
#
#   bF1 --&gt; bA[Item A]
#   bF1 --&gt; bB[Item B]
#   bF1 --&gt; bC[Item C]
#
#   bF2 --&gt; bD[Item D]
#   bF2 --&gt; bE[Item E]
#   bF2 --&gt; bF[Item F]
#
#   bF3 --&gt; bG[Item G]
#   bF3 --&gt; bH[Item H]
#   bF3 --&gt; bI[Item I]
# end
#
# linkStyle 12 stroke:#d62728,stroke-width:6px;
#
# ...

# %% [markdown]
# ## Ambiguous Replication (SEM)

# %%
# Out:
# <pre class="mermaid mermaid-js">graph LR
# subgraph O[Original]
#   Gf[Second-order factor] --&gt; F1[Factor 1]
#   Gf --&gt; F2[Factor 2]
#   Gf --&gt; F3[Factor 3]
#
#   F1 --&gt; A[Item A]
#   F1 --&gt; B[Item B]
#   F1 --&gt; C[Item C]
#
#   F2 --&gt; D[Item D]
#   F2 --&gt; E[Item E]
#   F2 --&gt; F[Item F]
#
#   F3 --&gt; G[Item G]
#   F3 --&gt; H[Item H]
#   F3 --&gt; I[Item I]
# end
#
# linkStyle 0 stroke:#d62728,stroke-width:6px;
# linkStyle 3 stroke:#d62728,stroke-width:6px;
# linkStyle 4 stroke:#d62728,stroke-width:6px;
# linkStyle 5 stroke:#d62728,stroke-width:6px;
#
# subgraph R[Replication]
#   bGf[Second-order factor] --&gt; bF1[Factor 1]
#   bGf --&gt; bF2[Factor 2]
#   bGf --&gt; bF3[Factor 3]
#
#   bF1 --&gt; bA[Item A]
#   bF1 --&gt; bB[Item B]
#   bF1 --&gt; bC[Item C]
#
#   bF2 --&gt; bD[Item D]
#   bF2 --&gt; bE[Item E]
#   bF2 --&gt; bF[Item F]
#
#   bF3 --&gt; bG[Item G]
#   bF3 --&gt; bH[Item H]
#   bF3 --&gt; bI[Item I]
# end
#
# ...
